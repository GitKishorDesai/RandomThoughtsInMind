# %% [markdown]
# Password Generator

# %%
import re
re.findall(r"([^A-Za-z0-9])", "s8d7a6f123gSAGDUYGJKh$$")
# Out:
# ['$', '$']

# %%
import re

password=input("Enter Password")
lowercase = "abcdefghijklmnopqrstuvwxyz"
uppercase = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
numbers = "0123456789"
symbols = "[]{}()*;/.,-_"
if len(password)<6:
  print("Password should contain more than 6 characters")

if not re.findall(r"([^A-Za-z0-9])", password):
  print("no special chars found :(")
# Out:
# Enter Passwordladhfo8h#FH

# %%
import random

lowercase = "abcdefghijklmnopqrstuvwxyz"
uppercase = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
numbers = "0123456789"
symbols = "[]{}()*;/.,-_"

all = lowercase + uppercase + numbers + symbols
# print(all)
length = 8
password ="".join(random.sample(all,length)) 
print(password)
# Out:
# sWQt21lI

# %%
print("Samarth")
# Out:
# Samarth

# %%
a="abcdABCD121324"
b=

# %%
list=["k","i","s","h","o","r"]
b="".join(random.sample(list,4))
print(b)
# Out:
# isho
